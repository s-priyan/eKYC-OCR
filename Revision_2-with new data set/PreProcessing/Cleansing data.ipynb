# %%
images_list = os.listdir("Imges/images-set-4")

# %%
import tensorflow as tf 
import numpy as np
import base64
import cv2
import matplotlib.pyplot as plt
import os, shutil, time, sys
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import tensorflow as tf
from tensorflow.keras.applications import VGG16
from termcolor import colored
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras import models,layers,optimizers
from PIL import Image
import numpy as np
from skimage import transform

# %%
#Check whether the GPUs are initialized (output:"1 Physical GPUs, 1 Logical GPUs")
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        # Currently, memory growth needs to be the same across GPUs
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
sel=np.random.randint(29370,size=4000)

# %%
sel
# Out:
# array([27945, 25463, 12957, ..., 12736, 12615,  8357])

# %%
images_list = os.listdir("Directory/DL_NEW_FRONT")

# %%
images_list[3]
# Out:
# '892d55ca-030a-4bdb-ae25-5792592c17e1_ID_IMAGE.jpg'

# %%
name_arr=[]
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory/DL_NEW_FRONT", name)
        shutil.move(image_path, "Directory_Cleansed/DL_NEW_FRONT")

# %%
sel=np.random.randint(20000,size=300)
images_list = os.listdir("Directory/DL_NEW_FRONT")
name_arr=os.listdir( "Directory_Cleansed/DL_NEW_FRONT")
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory/DL_NEW_FRONT", name)
        shutil.move(image_path, "Directory_Cleansed/dnf")

# %%
sel=np.random.randint(133680,size=4300)
images_list = os.listdir("Directory/NIC_OLD_BACK")
name_arr=[]
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory/NIC_OLD_BACK", name)
        shutil.move(image_path, "Directory_Cleansed/NIC_OLD_BACK")

# %%
sel=np.random.randint(4217,size=217)
images_list = os.listdir("Directory_Cleansed/NIC_OLD_BACK")
name_arr=os.listdir("Directory/NIC_OLD_BACK")
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory_Cleansed/NIC_OLD_BACK", name)
        shutil.move(image_path, "Directory/NIC_OLD_BACK")

# %%
sel=np.random.randint(133663,size=4100)
images_list = os.listdir("Directory/NIC_OLD_FRONT")
name_arr=[]
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory/NIC_OLD_FRONT", name)
        shutil.move(image_path, "Directory_Cleansed/NIC_OLD_FRONT")

# %%
sel=np.random.randint(4043,size=43)
images_list = os.listdir("Directory_Cleansed/NIC_OLD_FRONT")
name_arr=os.listdir("Directory/NIC_OLD_FRONT")
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory_Cleansed/NIC_OLD_FRONT", name)
        shutil.move(image_path, "Directory/NIC_OLD_FRONT")

# %%
sel=np.random.randint(37000,size=200)
images_list = os.listdir("Directory/NIC_NEW_FRONT")
name_arr=[]
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory/NIC_NEW_FRONT", name)
        shutil.move(image_path, "Directory_Cleansed/NIC_NEW_FRONT")

# %%
sel=np.random.randint(4058,size=58)
images_list = os.listdir("Directory_Cleansed/NIC_NEW_FRONT")
name_arr=os.listdir("Directory/NIC_NEW_FRONT")
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory_Cleansed/NIC_NEW_FRONT", name)
        shutil.move(image_path, "Directory/NIC_NEW_FRONT")

# %%
sel=np.random.randint(42731,size=4240)
images_list = os.listdir("Directory/NIC_NEW_BACK")
name_arr=[]
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory/NIC_NEW_BACK", name)
        shutil.move(image_path, "Directory_Cleansed/NIC_NEW_BACK")

# %%
sel=np.random.randint(4044,size=20)
images_list = os.listdir("Directory_Cleansed/NIC_NEW_BACK")
name_arr=os.listdir("Directory/NIC_NEW_BACK")
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory_Cleansed/NIC_NEW_BACK", name)
        shutil.move(image_path, "Directory/NIC_NEW_BACK")

# %%
sel=np.random.randint(50000,size=140)
images_list = os.listdir("Directory/UNKNOWN")
name_arr=[]
for i in sel:
    name=images_list[i]
    if name not in name_arr:
        name_arr.append(name)
        image_path = os.path.join("Directory/UNKNOWN", name)
        shutil.move(image_path, "Directory_Cleansed/UNKNOWN")

# %%
img_src=cv2.imread("Directory/DL_NEW_FRONT/0a0aefb1-fd11-4211-9168-c1e3ce4d9fb8_ID_IMAGE.jpg")
img_rst=cv2.blur(img_src,(10,10))
cv2.imwrite("result.jpg",img_rst)
# Out:
# True

# %%
dire="Directory_Cleansed/DL_NEW_FRONT"
rec="blured/NEW"
r=20
for i in range (0,2):
    r=r+10
    images_list = os.listdir(dire)
    sel=np.random.randint(1500,size=20)
    for t in sel:
        name=images_list[t]
        image_path = os.path.join(dire, name)
        img_src=cv2.imread(image_path)
        img_rst=cv2.blur(img_src,(r,r))
       #namemod=name+"dd"
        saveat=os.path.join(rec, name)
        cv2.imwrite(saveat,img_rst)

# %%
name+"rf"
# Out:
# '94f89bd0-d7c3-4f7d-b6b1-74734f01d003_ID_IMAGE.jpgrf'

# %%
dire="Directory_Cleansed/DL_NEW_BACK"
images_list = os.listdir(dire)
sel=np.random.randint(1500,size=23)
for i in sel:
    name=images_list[i]
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    newimg=cv2.flip(img_src,0)
    newname="pft"+name[0:10]+".jpg"
    saveat=os.path.join(dire, newname)
    cv2.imwrite(saveat,newimg)

# %%
dire="Directory_Cleansed/PASSPORT_LOCAL"
rec="pplocal"
images_list = os.listdir(dire)
sel=np.random.randint(4000,size=79)
for i in sel:
    name=images_list[i]
    image_path = os.path.join(dire, name)
    shutil.move(image_path, rec)

# %%
dire="train_dir/DL_NEW_BACK"
rec="train_new_dir/DL_NEW_BACK"
images_list = os.listdir(dire)
#sel=np.random.randint(1500,size=23)
for name in images_list:
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    #newimg=cv2.flip(img_src,0)
    newname="newimg"+name+".jpg"
    saveat=os.path.join(rec, newname)
    cv2.imwrite(saveat,img_src)

# %%
dire="train_dir/DL_NEW_FRONT"
rec="train_new_dir/DL_NEW_FRONT"
images_list = os.listdir(dire)
#sel=np.random.randint(1500,size=23)
r=0
for name in images_list:
    r+=1
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    #newimg=cv2.flip(img_src,0)
    newname="newimg"+str(r)+name+".jpg"
    saveat=os.path.join(rec, newname)
    cv2.imwrite(saveat,img_src)

# %%
dire="train_dir/NIC_NEW_BACK"
rec="train_new_dir/NIC_NEW_BACK"
images_list = os.listdir(dire)
r=0
#sel=np.random.randint(1500,size=23)
for name in images_list:
    r+=1
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    #newimg=cv2.flip(img_src,0)
    newname="newimg"+str(r)+name+".jpg"
    saveat=os.path.join(rec, newname)
    cv2.imwrite(saveat,img_src)

# %%
dire="train_dir/NIC_NEW_FRONT"
rec="train_new_dir/NIC_NEW_FRONT"
images_list = os.listdir(dire)
r=0
#sel=np.random.randint(1500,size=23)
for name in images_list:
    r+=1
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    #newimg=cv2.flip(img_src,0)
    newname="newimg"+str(r)+name+".jpg"
    saveat=os.path.join(rec, newname)
    cv2.imwrite(saveat,img_src)

# %%
dire="train_dir/NIC_OLD_FRONT"
rec="train_new_dir/NIC_OLD_FRONT"
images_list = os.listdir(dire)
r=0
#sel=np.random.randint(1500,size=23)
for name in images_list:
    r+=1
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    #newimg=cv2.flip(img_src,0)
    newname="newimg"+str(r)+name+".jpg"
    saveat=os.path.join(rec, newname)
    cv2.imwrite(saveat,img_src)

# %%
dire="train_dir/NIC_OLD_BACK"
rec="train_new_dir/NIC_OLD_BACK"
images_list = os.listdir(dire)
r=0
#sel=np.random.randint(1500,size=23)
for name in images_list:
    r+=1
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    #newimg=cv2.flip(img_src,0)
    newname="newimg"+str(r)+name+".jpg"
    saveat=os.path.join(rec, newname)
    cv2.imwrite(saveat,img_src)

# %%
dire="train_dir/PASSPORT_LOCAL"
rec="train_new_dir/PASSPORT_LOCAL"
images_list = os.listdir(dire)
r=0
#sel=np.random.randint(1500,size=23)
for name in images_list:
    r+=1
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    #newimg=cv2.flip(img_src,0)
    newname="newimg"+str(r)+name+".jpg"
    saveat=os.path.join(rec, newname)
    cv2.imwrite(saveat,img_src)

# %%
dire="train_dir/PASSPORT_FOREIGN"
rec="train_new_dir/PASSPORT_FOREIGN"
images_list = os.listdir(dire)
r=0
#sel=np.random.randint(1500,size=23)
for name in images_list:
    r+=1
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    #newimg=cv2.flip(img_src,0)
    newname="newimg"+str(r)+name+".jpg"
    saveat=os.path.join(rec, newname)
    cv2.imwrite(saveat,img_src)

# %%
dire="train_dir/UNKNOWN"
rec="train_new_dir/UNKNOWN"
images_list = os.listdir(dire)
r=0
#sel=np.random.randint(1500,size=23)
for name in images_list:
    r+=1
    image_path = os.path.join(dire, name)
    #print(image_path)
    img_src=cv2.imread(image_path)
    #newimg=cv2.flip(img_src,0)
    newname="newimg"+str(r)+name+".jpg"
    saveat=os.path.join(rec, newname)
    cv2.imwrite(saveat,img_src)

# %%
dire="train_new_dir"
rec="train_new"
follist=os.listdir(dire)
#sel=np.random.randint(9000,size=900)
r=0
for folder in follist:
    path=os.path.join(dire,folder)
    images_list = os.listdir(path)
#sel=np.random.randint(1500,size=23)
    for name in images_list:
        #name=images_list[i]
        r+=1
        image_path = os.path.join(path, name)
        #print(image_path)
        img_src=cv2.imread(image_path)
        #newimg=cv2.flip(img_src,0)
        newname="rawimg"+str(r)+".jpg"
        saveat=os.path.join(rec, folder,newname)
        cv2.imwrite(saveat,img_src)

# %%
dire="val_new_dir/PASSPORT_LOCAL"
rec="train_new/PASSPORT_LOCAL"
# follist=os.listdir(dire)
# #sel=np.random.randint(9000,size=900)
r=0
# for folder in follist:
#     path=os.path.join(dire,folder)
images_list = os.listdir(dire)
sel=np.random.randint(2000,size=88)
for i in sel:
    name=images_list[i]
    r+=1
    image_path = os.path.join(dire, name)
        #print(image_path)
    img_src=cv2.imread(image_path)
        #newimg=cv2.flip(img_src,0)
    newname="rawimg45"+str(r)+".jpg"
    saveat=os.path.join(rec,newname)
    cv2.imwrite(saveat,img_src)

# %%
os.path.join(dire,"erf","ghj")
# Out:
# 'train_new_dir/erf/ghj'

# %%
dire="train_new/PASSPORT_LOCAL_1"
rec="train_new/PASSPORT_LOCAL"
# follist=os.listdir(dire)
# #sel=np.random.randint(9000,size=900)
r=0
# for folder in follist:
#     path=os.path.join(dire,folder)
images_list = os.listdir(dire)
#sel=np.random.randint(2000,size=88)
for name in images_list:
    #name=images_list[i]
    r+=1
    image_path = os.path.join(dire, name)
        #print(image_path)
    img_src=cv2.imread(image_path)
        #newimg=cv2.flip(img_src,0)
    newname="rawimage"+str(r)+".jpg"
    saveat=os.path.join(rec,newname)
    cv2.imwrite(saveat,img_src)

# %%
sel=[]
while(True):
    r=np.random.randint(1,9000)
    if r not in sel: 
        sel.append(r)
    if len(sel)==900:
        break

# %%
sel
# Out:
# [3597,
#  4723,
#  760,
#  8810,
#  4750,
#  7835,
#  6460,
#  5518,
#  2400,
#  7893,
#  4567,
#  4524,
#  4389,
#  5819,
#  2007,
#  4643,
#  6615,
#  418,
#  3299,
#  1744,
#  8222,
#  5851,
#  889,
#  8881,
#  3459,
#  5431,
#  859,
#  8360,
#  1620,
#  4117,
#  3407,
#  6736,
#  2054,
#  7441,
#  6936,
#  7371,
#  8706,
#  3402,
#  8658,
#  2777,
#  3186,
#  1403,
#  8245,
#  1470,
#  7838,
#  7122,
#  4693,
#  3325,
#  4040,
#  4883,
#  6910,
#  4820,
#  5315,
#  3033,
#  2265,
#  2223,
#  7156,
#  971,
#  6837,
#  7099,
#  8789,
#  7344,
#  4782,
#  1622,
#  3005,
#  8307,
#  3853,
#  4491,
#  3829,
#  4651,
#  8896,
#  4610,
#  2268,
#  443,
#  1270,
#  4897,
#  6613,
#  1396,
#  175,
#  1941,
#  3195,
#  7648,
#  6902,
#  8012,
#  4284,
#  3986,
#  2049,
#  6574,
#  4170,
#  4204,
#  2949,
#  3945,
#  4481,
#  3811,
#  6905,
#  7566,
#  728,
#  831,
#  8528,
#  7006,
#  5091,
#  1930,
#  4454,
#  1193,
#  6732,
#  8986,
#  2832,
#  6940,
#  5411,
#  8140,
#  5752,
#  8946,
# ...

# %%
dire="train_new"
rec="val_new_dir"
follist=os.listdir(dire)
#sel=np.random.randint(9000,size=900)
#r=0
for folder in follist:
    path=os.path.join(dire,folder)
    images_list = os.listdir(path)
    #sel=np.random.randint(9000,size=900)
    for i in sel:
        name=images_list[i]
        #r+=1
        image_path = os.path.join(path, name)
        #print(image_path)
        #img_src=cv2.imread(image_path)
        #newimg=cv2.flip(img_src,0)
        #newname="rawimg"+str(r)+".jpg"
        saveat=os.path.join(rec, folder)
        shutil.move(image_path, saveat)

# %%
sel=[]
while(True):
    r=np.random.randint(1,8100)
    if r not in sel: 
        sel.append(r)
    if len(sel)==900:
        break

# %%
dire="train_new"
rec="test_new_dir"
follist=os.listdir(dire)
#sel=np.random.randint(9000,size=900)
#r=0
for folder in follist:
    path=os.path.join(dire,folder)
    images_list = os.listdir(path)
    #sel=np.random.randint(8000,size=900)
    for i in sel:
        name=images_list[i]
        #r+=1
        image_path = os.path.join(path, name)
        #print(image_path)
        #img_src=cv2.imread(image_path)
        #newimg=cv2.flip(img_src,0)
        #newname="rawimg"+str(r)+".jpg"
        saveat=os.path.join(rec, folder)
        shutil.move(image_path, saveat)

# %%
dire="train_new_dir/NIC_NEW_BACK"
rec="val"
images_list=os.listdir(dire)
for i in sel:
    name=images_list[i]
        #r+=1
    image_path = os.path.join(path, name)
        #print(image_path)
        #img_src=cv2.imread(image_path)
        #newimg=cv2.flip(img_src,0)
        #newname="rawimg"+str(r)+".jpg"
    saveat=os.path.join(rec, folder)
    shutil.move(image_path, saveat)

# %%
sel=[]
while(True):
    r=np.random.randint(1,700)
    if r not in sel: 
        sel.append(r)
    if len(sel)==100:
        break
        
dire="val_new_dir/DL_NEW_FRONT"
rec="val_new_dir/movehere"
images_list = os.listdir(dire)
#sel=np.random.randint(1500,size=23)
for i in sel:
    name=images_list[i]
    image_path = os.path.join(dire, name)
    #print(image_path)
    #saveat=os.path.join(rec, name)
    shutil.move(image_path, rec)
#     img_src=cv2.imread(image_path)
#     newimg=cv2.flip(img_src,0)
#     newname="pft"+name[0:10]+".jpg"
#     saveat=os.path.join(dire, newname)
#     cv2.imwrite(saveat,newimg)

# %%
rec="val_new_dir/movehere2"
dire="val_new_dir/movehere"
images_list = os.listdir(dire)
i=0
#sel=np.random.randint(1500,size=23)
for name in images_list:
    #name=images_list[i]
    i+=1
    image_path = os.path.join(dire, name)
    #print(image_path)
    #saveat=os.path.join(rec, name)
    #shutil.move(image_path, rec)
    img_src=cv2.imread(image_path)
    if i%2==0:
        newimg=cv2.rotate(img_src,cv2.ROTATE_90_CLOCKWISE)
    else:
        newimg=cv2.rotate(img_src,cv2.ROTATE_90_COUNTERCLOCKWISE)
    #newname="pft"+name[0:10]+".jpg"
    saveat=os.path.join(rec, name)
    cv2.imwrite(saveat,newimg)

# %%
rec="val_new_dir/DL_NEW_FRONT"
dire="val_new_dir/movehere2"
images_list = os.listdir(dire)
#sel=np.random.randint(1500,size=23)
for name in images_list:
    #name=images_list[i]
    image_path = os.path.join(dire, name)
    #print(image_path)
    #saveat=os.path.join(rec, name)
    shutil.move(image_path, rec)

# %%
img=cv2.imread("IMG_4119.jpg")
saveat="blur_example"

img6=cv2.blur(img,(70,70))
img7=cv2.blur(img,(80,80))
img8=cv2.blur(img,(90,90))
img9=cv2.blur(img,(100,100))
#img5=cv2.blur(img,(60,60))

cv2.imwrite("blur_example/6.jpg",img6)
cv2.imwrite("blur_example/7.jpg",img7)
cv2.imwrite("blur_example/8.jpg",img8)
cv2.imwrite("blur_example/9.jpg",img9)
#cv2.imwrite("blur_example/5.jpg",img5)
# Out:
# True

# %%
saveat
# Out:
# 'val_new_dir/movehere2/rawimg69237.jpg'

# %%
img=cv2.imread("IMG_4119.JPG")
saveat="blur_example"
img1=cv2.blur(img,(20,20))
img2=cv2.blur(img,(30,30))
img3=cv2.blur(img,(40,40))
img4=cv2.blur(img,(50,50))
img5=cv2.blur(img,(60,60))
#img5=cv2.blur(img,(60,60))
cv2.imwrite("blur_example/1.jpg",img1)
cv2.imwrite("blur_example/2.jpg",img2)
cv2.imwrite("blur_example/3.jpg",img3)
cv2.imwrite("blur_example/4.jpg",img4)
cv2.imwrite("blur_example/5.jpg",img5)
#cv2.imwrite("blur_example/5.jpg",i5)
# Out:
# True
